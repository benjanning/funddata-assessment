# %% [markdown]
# ## Exercise
# ### Plot bar charts or histograms of any three different distributions listed at the following link:
# https://numpy.org/doc/stable/reference/random/generator.html#distributions
#
# ***
#
# ![image.png](attachment:image.png)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Logistic Distribution

# Set the Loc, Scale (The Parameter) 
loc, scale = 10, 1

# Set variable name and add in the number of values
x = np.random.default_rng().logistic(loc, scale, 10000)

# Make Histogram, Define Bin (Tower or Bar) size, 

plt.hist(x, bins=50)

plt.show()

# %%
# Plotting against the Distribution
#original code

loc, scale = 10, 1

x = np.random.default_rng().logistic(loc, scale, 10000)

plt.hist(x, bins=50)

#defining the variable, setting the values

def logist(x, loc, scale):
    return np.exp((loc-x)/scale)/(scale*(1+np.exp((loc-x)/scale))**2)
lgst_val = logist(bins, loc, scale)
plt.plot(bins, lgst_val * count.max() / lgst_val.max())
plt.show()

# %%
# Dirichlet

#Set the variable name and values (sample length, width, the maximum value)
# Transpose - change row elements into column elements and vice versa

s = np.random.default_rng().dirichlet((15, 5, 7), 30).transpose()

plt.barh(range(30), s[0])
plt.barh(range(30), s[1], left=s[0], color='g')
plt.barh(range(30), s[2], left=s[0]+s[1], color='r')
plt.title("Lengths of a Strand of Hair")
plt.show()

# %%
# Wald

# Set the values for mean, scale and size, as well as tower size.  

a = plt.hist(np.random.default_rng().wald(3, 2, 100000), bins=200) 
plt.show()

# %% [markdown]
# ## References
#
# ***
#
# 1. Random Generator. https://numpy.org/doc/stable/reference/random/generated/numpy.random.Generator.logistic.html#numpy.random.Generator.logistic
#
# 2. Pyplot Barh Function in Python. https://www.geeksforgeeks.org/matplotlib-pyplot-barh-function-in-python/#:~:text=Output%20%3A,values%20as%20the%20X%2Daxis.
