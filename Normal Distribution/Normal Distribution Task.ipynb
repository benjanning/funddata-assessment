# %% [markdown]
# # <h1><center>Normal Distribution</center></h1>
#
# ![image-2.png](attachment:image-2.png)
#
# Author: Ben Janning
#
# ***

# %% [markdown]
# ## <h1><center>What is the Normal Distribution?</center></h1>
#
# ***

# %% [markdown]
# The normal distribution, also referred to as the gaussian distribution, is a probability distribution characterized by its symmetry around the mean. This means that data points close to the mean are more likely to occur than those that are further away from it. [1]
#
# When shown on a graph, the normal distribution appears as a Bell Curve.
#
# Many naturally-occurring phenomena tend to approximate the normal distribution.
#
# In a normal distribution the mean is zero and the standard deviation is 1. It has zero skew and a kurtosis of 3.
#
# Kurtosis: The sharpness of the peak of a frequency-distribution curve.
#
# The standard normal distribution has two parameters: the mean and the standard deviation (which determines the amount of dispersion away from the mean).
#
# A small standard deviation (compared with the mean) produces a steep graph, whereas a large standard deviation (again compared with the mean) produces a flat graph. [3]

# %% [markdown]
# ## <h1><center>How to Recognise a Normal Distribution</center></h1>
#
# ***
#
# Normal distributions have key characteristics that are easy to spot in graphs:
#
# The mean, median and mode are exactly the same.
#
# The distribution is symmetric about the mean—half the values fall below the mean and half above the mean.
#
# The distribution can be described by two values: the mean and the standard deviation.
#
# The mean determines where the peak of the curve is centered. Increasing the mean moves the curve right, while decreasing it moves the curve left.
#
# ![image.png](attachment:image.png)
#
# The standard deviation stretches or squeezes the curve. A small standard deviation results in a narrow curve, while a large standard deviation leads to a wide curve. [4]
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## <h1><center>Why is the Normal Distribution Important?</center></h1>
#
# ![image.png](attachment:image.png)
#
# ***

# %% [markdown]
# ### Psychological and Educational Variables
#
# One of the main reasons the normal distribution is significant is that it is often used to model psychological and educational variables. Many such variables, such as measures of reading ability, introversion, job satisfaction, and memory, are approximately normally distributed.  [10]
#
# ### Nature
#
# The normal distribution is considered the most important probability distribution in statistics due to its ability to accurately represent the distribution of values for many natural phenomena. [11]
#
# ### Industry
#
# The normal distribution is frequently used in industries and companies as a tool for decision-making. It can provide valuable insights into customer behavior, market trends, and purchasing patterns. Some examples of industries that utilize this type of distribution analysis include:
#
# Sales and Marketing
#
# Accounting
#
# Finance and Stock Market Analysis
#
# Politics
#
# Logistics
#
# Manufacturing. [12]
#
# ### Decisions
#
# When companies look for a marker to make important decisions, they may use this distribution analysis to help. Examples include:
#
# Negotiating contracts
#
# Purchasing materials
#
# Pricing products
#
# ### Population
#
# Factors in a population, such as height birth weight, IQ, Shoe Size, Income Distribution all follow the normal distribution.
#
# The height of a population is often approximately normally distributed, meaning that most individuals in the population are of average height, with an approximately equal number of people being taller and shorter than average. However, a small number of individuals may be extremely tall or short. This distribution is influenced by various genetic and environmental factors. In other words, the distribution of height within a population tends to follow a normal curve.  [13]

# %% [markdown]
# ## <h1><center>How Did Normal Distribution Receive its Name?</center></h1>
#
# ***
#
# The normal distribution is technically known as the Gaussian distribution, however it took on the terminology "normal" following scientific publications in the 19th century showing that many natural phenomena appeared to "deviate normally" from the mean. This idea of "normal variability" was made popular as the "normal curve" by the naturalist Sir Francis Galton in his 1889 work, Natural Inheritance. [1]

# %% [markdown]
# The normal distribution is widely considered the most important probability distribution in statistics because it accurately represents the distribution of many continuous data sets found in nature and psychology. When such data is compiled and plotted, it often exhibits a bell-shaped curve characteristic of the normal distribution. [2]
#
# For example, if we randomly sampled 100 individuals we would expect to see a normal distribution frequency curve for many continuous variables, such as IQ, height, weight and blood pressure.

# %% [markdown]
# ## <h1><center>Formula for the Normal Distribution</center></h1>
#
# ***
#
# ![image.png](attachment:image.png)

# %% [markdown]
# In the formula above:
#
# f(x) = Probability Density Function
#
# σ	=	Standard deviation
#
# μ	=	Mean

# %% [markdown]
# ## <h1><center>Different Types of Averages</center></h1>
#
# ![image.png](attachment:image.png)
#
# In a Normal Distribution, The Mean, Mode and Median are all equal.  However, they all have their own definitions and functions.
# The Mean, Mode and Median are measurements of central tendency. In other words, it tells you where the “Middle” of a data set it. Each of these statistics defines the middle differently: [6]
#
# ***

# %% [markdown]
# ### The Mean
#
# The mean (informally, the “average“) is found by adding all of the numbers together and dividing by the number of items in the set:

# %%
(10 + 10 + 20 + 40 + 70) / 5
# Out:
# 30.0

# %% [markdown]
# ### The Mode
#
# The mode is the number that occurs most frequently:

# %%
# Using Python's built in Functions [7]

from statistics import mode
mode([10, 10, 20, 40, 70])
# Out:
# 10

# %% [markdown]
# ### The Median
#
# The median is the number that lies in the middle. Or put another way, the value separating the higher half from the lower half of a data sample.

# %%
from statistics import median
median([10, 10, 20, 40, 70])
# Out:
# 20

# %% [markdown]
# ### <h1><center>The Empirical Rule</center></h1>
#
# ![image.png](attachment:image.png)
#
# ***
#
# The Emperical Rule says that:
#
# 68% of the observations will lie within +/- 1 standard deviation from the mean.
#
# 95% of the observations will lie within +/- 2 standard deviations from the mean.
#
# 7% of the observations will lie within +/- 3 standard deviations from the mean. [5]

# %% [markdown]
# ## <h1><center>Code Examples of Normal Distribution</center></h1>

# %% [markdown]
# ### Plotting Normal Distribution on a Histogram

# %%
# Import everything we will need

import numpy as np
import matplotlib.pyplot as plt

# %%
# Draw samples from the distribution: [9]

mu, sigma = 0, 0.1 # mean and standard deviation
s = np.random.normal(mu, sigma, 1000)

# %%
# Verify the mean and the variance:

abs(mu - np.mean(s))
0.0  # may vary
# Out:
# 0.0

# %%
abs(sigma - np.std(s, ddof=1))
0.1  # may vary
# Out:
# 0.1

# %%
# Display the histogram of the samples, along with the probability density function:

import matplotlib.pyplot as plt
count, bins, ignored = plt.hist(s, 30, density=True)
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *
               np.exp( - (bins - mu)**2 / (2 * sigma**2) ),
         linewidth=2, color='r')

# Adding a Title
plt.title('Normal Distribution', fontsize=14)

plt.show()

# %% [markdown]
# ### Arrays

# %%
# Two-by-four array of samples from the normal distribution with mean 3 and standard deviation 2.5:
from numpy import array

np.random.normal(3, 2.5, size=(2, 4))
array([[-4.49401501,  4.00950034, -1.81814867,  7.29718677],   # random
       [ 0.39924804,  4.68456316,  4.99394529,  4.84057254]])  # random
# Out:
# array([[-4.49401501,  4.00950034, -1.81814867,  7.29718677],
#        [ 0.39924804,  4.68456316,  4.99394529,  4.84057254]])

# %% [markdown]
# ### Using Random Number Generator

# %%
# Create new, seeded random number generator. [14]
rng = np.random.default_rng(0)

# Generate 1000 numbers on a standard normal distribution.
samples = rng.standard_normal(1000)

# %%
# Create a figure.
fig, ax = plt.subplots()

# Create histogram.
ax.hist(samples, bins=100)

# Add Market to Histogram to show Mean.
plt.axvline(x=0, color='red');

# Adding a Title.
plt.title('Normal Distribution', fontsize=14)
# Out:
# Text(0.5, 1.0, 'Normal Distribution')

# %% [markdown]
# ## <h1><center>The Z-Score</center></h1>
#
# ***
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### What Does the Z-Score Tell Us?
#
# ***

# %% [markdown]
# A z-score indicates the raw score's distance from the mean in standard deviation units, effectively describing its position within the distribution. [16]
#
# The value is positive if it lies above the mean and negative if it lies below.
#
# It is also often referred to as a Standard Score.

# %% [markdown]
# ### Why are Z-Scores Important?
#
# ***
#
# It is useful to convert raw values into z-scores because:
#
# 1) It helps determine the probability of a score occuring within a Normal Distribution
#
# 2) It allows us to compare scores from different samples, which may have different standard deviations and means.

# %% [markdown]
# ### Formula
#
# ***
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Interpreting the Z-Score
#
# ***

# %% [markdown]
# The z-score indicates how many standard deviations a raw score is from the mean.
#
# A score of 0 is on the mean, while a positive z-score means the raw score is above the mean and a negative z-score indicates that it is below the mean.
#
# For example, a z-score of +1 is 1 standard deviation above the mean, while a z-score of -2 is 2 standard deviations below the mean.

# %% [markdown]
# ###  Z-Score Code Example:
#
# ***

# %%
# Generate a sample of normally distributed data
sample = np.random.normal(50, 10, 1000)

# Calculate the Z score for a value of 60
z_score = (60 - np.mean(sample)) / np.std(sample)
print(f"The Z score for the value 60 is {z_score:.2f}")

# Plot the sample data and mark the value of 60 with a vertical line
plt.hist(sample, bins=25, density=True)
plt.axvline(60, color='r', linestyle='--')
plt.show()
# Out:
# The Z score for the value 60 is 1.02

# %% [markdown]
# ## <h1><center>The Z-Table</center></h1>
#
# ***
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# The Z-Table represents the area under the curve to the left of a Z-Score. [17]
#
# It represents the probability that z-values will fall within a region of the standard normal distribution.
#
# The table is divided into negative and positive Z-Scores. Negative Z-Scores are below the mean, while positive Z-Scores are above the mean.

# %% [markdown]
# ### Negative Z-Table Example:
#
# ![image.png](attachment:image.png)
#
# ***
#
# ### Positive Z-Table Example:
#
# ![image-2.png](attachment:image-2.png)
#
# ***

# %% [markdown]
# ### Using the Z-Table
#
# ***

# %% [markdown]
# The Components of the Z-Table Represent the Following:
#
# Row headings define the z-score to the tenth’s place.
#
# Column headings add the z-scores’ hundredth’s place.
#
# Cells within the table represent the area under the standard normal curve to the left of the z-score.

# %% [markdown]
# For example, to find the area for z = -2.23, look at the row (-2.2) and column (0.03) intersection, as shown in the truncated z-table below.
#
# ![image.png](attachment:image.png)
#
# The area to the left of z = -2.23 is 0.01287. The probability of values falling below this value in a normally distributed population is 0.01287 or 1.287%.

# %% [markdown]
# ### Z-Table Code Example:
#
# ***

# %%
import scipy.stats as stats

# Define a function to look up the probability of a Z score in the Z table
def z_table_lookup(z_score):
    # Use the scipy.stats.norm.cdf() function to find the probability of a Z score. [20]
    probability = stats.norm.cdf(z_score)
    print(f"The probability of a Z score of {z_score:.2f} or less is {probability:.2f}")

# Look up the probability of a Z score of 1.96 or less
z_table_lookup(1.96)

# Look up the probability of a Z score of -1.96 or less
z_table_lookup(-1.96)

# Look up the probability of a Z score of 0 or less
z_table_lookup(0)
# Out:
# The probability of a Z score of 1.96 or less is 0.98
# The probability of a Z score of -1.96 or less is 0.02
# The probability of a Z score of 0.00 or less is 0.50

# %% [markdown]
# ## <h1><center>Central Limit Theorem</center></h1>
#
# ![image.png](attachment:image.png)
#
# ***

# %% [markdown]
# ### What is Central Limit Theorem?
#
# ***
#
# According to the Central Limit Theorem, as the sample size increases, the distribution of sample means becomes increasingly approximated by a normal distribution, regardless of the shape of the population's distribution. [18]
#
# Sample sizes equal to or greater than 30 are usually considered large enough for the Theorem to apply.
#
# In the CLT sample means and standard deviations will equal the population mean and standard deviation.
#
# A large sample size can predict the characteristics of a population more accurately.
#
# CLT is often used in finance to analyze collections of securities in order to estimate portfolio distributions and traits for returns, risk, and correlation.

# %% [markdown]
# ###  Key Characteristics
#
# ***
#
# Sampling is Successive, meaning some samples are common in previous studies.
#
# Sampling is Random, in order for all samples to have the same probability of being picked.
#
# Samples should be independent.  The samples chosen should have no effect on other samples or future results.
#
# Samples should be limited.  For example: 10% is often a suitable percentage of a population for a study.  As studies grow larger, so do sample sizes.
#
# Sample size is increasing. The central limit theorem is relevant as more samples are selected.

# %% [markdown]
# ### What Makes the Central Limit Theorem Useful?
#
# ***

# %% [markdown]
# As The central limit theorem allows us to assume that the sampling distribution of the mean will be normally-distributed in most cases it can be used to analyse large data sets.
#
# It is often used in areas such as: [19]
#
# 1) Economics:
# If a study of 50 people shows that people between the ages of 30 and 35 earn €30,000 on average per year in a certain town, that study can be applied to the whole town.
#
# 2) Biology:
# If a biologist finds that the sample mean height of 30 plants is 10.3 inches, then their approximation for the population mean height will also be 10.3 inches.
#
# 3) Manufacturing:
# Manufacturing Plants can use CLT to estimate how many products are faulty on average.  If 50 products are chosen at random and 1 is defective then the assumption will be made that 2% of the products are faulty.
#
# 4) Surveys:
# Surveys generally focus on a small sub set of a population and can ask a wide range of questions.  If for example 10% of people respond to a survey about job satisfaction that they are unsatisfied that will be used to estimate the broader population's job satisfaction too.
#
# 5) Agriculture:
# In order to estimate the crop yield generated, a study may focus on 30 different wheat fields and measure their selective yields.  If the average yield of those fields is 300 kg, then the average yield for all wheat fields will be 300 kg.

# %% [markdown]
# ### Central Limit Theorem - Code Example:
#
# ***

# %%
# Define the salary dataset
salaries = [50000, 55000, 60000, 65000, 70000, 75000, 80000, 85000, 90000, 95000]

# Set the population mean and standard deviation
pop_mean = np.mean(salaries)
pop_stddev = np.std(salaries)

# Set the sample size
sample_size = 1000

# Draw a sample of size `sample_size` from the population
sample = np.random.normal(pop_mean, pop_stddev, sample_size)

# Calculate the sample mean and standard deviation
sample_mean = np.mean(sample)
sample_stddev = np.std(sample)

# Use the Central Limit Theorem to calculate the standard error of the mean
sem = sample_stddev / np.sqrt(sample_size)

# Calculate the 95% confidence interval [21]
confidence_interval = 1.96 * sem

print(f"The sample mean is {sample_mean:.2f} with a standard error of {sem:.2f}.")
print(f"The 95% confidence interval is ({sample_mean - confidence_interval:.2f}, {sample_mean + confidence_interval:.2f}).")
# Out:
# The sample mean is 72498.84 with a standard error of 459.49.
# The 95% confidence interval is (71598.23, 73399.44).

# %% [markdown]
# ## <h1><center>Outliers</center></h1>
#
#
# ***
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### What are Outliers?
#
# ***

# %% [markdown]
# An outlier is any data point that is distinctly different from the rest of your data points.
#
# One definition of outliers is data that are more than 1.5 times the inter-quartile range before Q1 or after Q3. Since the quartiles for the standard normal distribution are +/-.67, the IQR = 1.34, hence 1.5 times 1.34 = 2.01, and outliers are less than -2.68 or greater than 2.68. [22]
#
# In general, outliers belong to one of two categories: a mistake in the data or a true outlier.

# %% [markdown]
# ### How to Detect Outliers?
#
# ***
#
# Outliers can be detected by using graphical methods, such as Scatter Plots, or Box Plots, as well as statistical methods, such as Percentile Capping, IQR (inter quantile range) and Standard Deviation Method.

# %% [markdown]
# ### Graphical Methods
#
# ***

# %%
# Scatter Plot

# Generate a random normal distribution
mean = 0
std = 1
data = np.random.normal(mean, std, 1000)

# Add an outlier to the distribution
outlier = data.max() + 3 * std
data = np.append(data, outlier)

# Plot the data as a scatter plot
plt.scatter(range(len(data)), data)

# Show the plot
plt.show()

# %% [markdown]
# In the example above we can clearly see an outlier in the top right corner of the scatter plot.  Let's present this another way, by using a box plot below.

# %%
# Generate a random normal distribution
mean = 0
std = 1
data = np.random.normal(mean, std, 1000)

# Add an outlier to the distribution
outlier = data.max() + 3 * std
data = np.append(data, outlier)

# Plot the data as a box plot
plt.boxplot(data)

# Show the plot
plt.show()

# %% [markdown]
# In a box plot, the box represents the interquartile range (IQR) of the data, which is the range between the 25th and 75th percentile. The line within the box represents the median of the data. The whiskers of the box plot extend to the minimum and maximum values of the data, except for outliers, which are plotted individually as points outside of the whiskers.

# %% [markdown]
# ### Statistical Methods
#
# ***

# %% [markdown]
# #### Percentile Capping
#
# ***
#
# Percentile Capping means that data points less than the value at first percentile or greater than value at 99th percentile could be considered outliers.

# %%
# Perentile Capping

# Generate a random normal distribution
mean = 0
std = 1
data = np.random.normal(mean, std, 1000)

# Add an outlier to the distribution
outlier = data.max() + 3 * std
data = np.append(data, outlier)

# Cap the values of the data at the 95th percentile
upper_threshold = np.percentile(data, 95)
data = np.clip(data, a_min=None, a_max=upper_threshold)

# Print the values of the data
print(data)
# Out:
# [-1.39611827 -0.41102451  0.75083008 ...  0.5046302   1.64570613
#   1.64570613]

# %% [markdown]
# The numpy clip function caps the values of the data at the 95th percentile, so any values above the 95th percentile will be set to the 95th percentile. This will effectively remove the outlier from the data, as it will be set to the same value as the 95th percentile. [24]
#
# We can then use the data array to plot the distribution in a graphical format.

# %%
# Plot the data as a scatter plot
plt.scatter(range(len(data)), data)

# Show the plot
plt.show()

# %% [markdown]
# #### IQR (Inter Quantile Range)
#
# ***
#
# If a value is higher than the 1.5*IQR above the upper quartile (Q3), the value will be considered as outlier. Similarly, if a value is lower than the 1.5*IQR below the lower quartile (Q1), the value will be considered as outlier.

# %%
# Generate a random normal distribution
mean = 0
std = 1
data = np.random.normal(mean, std, 1000)

# Add an outlier to the distribution
outlier = data.max() + 3 * std
data = np.append(data, outlier)

# Calculate the IQR of the data
q1 = np.percentile(data, 25)
q3 = np.percentile(data, 75)
iqr = q3 - q1

# Identify any values outside of the IQR range as potential outliers
lower_threshold = q1 - 1.5 * iqr
upper_threshold = q3 + 1.5 * iqr
outliers = data[(data < lower_threshold) | (data > upper_threshold)]

# Print the values of the potential outliers
print(outliers)
# Out:
# [-3.26424064  2.78446421  2.96119767  3.52233176 -2.73460903  3.61920868
#   3.10441322  2.89938188  6.61920868]

# %%
# Visualise the data.

# Plot the data as a scatter plot
plt.scatter(range(len(data)), data)

# Mark the outlier points on the scatter plot
plt.scatter(range(len(outliers)), outliers, color='red')

# Show the plot
plt.show()

# %% [markdown]
# #### Standard Deviation
#
# ***

# %% [markdown]
# Standard deviation is a metric of variance i.e. how much the individual data points are spread out from the mean.[26] If a value is higher or lower by three Standard Deviations from the mean, it is considered as outlier.  This is based on the characteristics of a normal distribution for which 99.87% of the data appear within this range.

# %%
# Standard Deviation

# Generate a random normal distribution
mean = 0
std = 1
data = np.random.normal(mean, std, 1000)

# Add an outlier to the distribution
outlier = data.max() + 3 * std
data = np.append(data, outlier)

# Calculate the standard deviation of the data
data_std = np.std(data)

# Identify any values outside of two standard deviations from the mean as potential outliers
lower_threshold = mean - 2 * data_std
upper_threshold = mean + 2 * data_std
outliers = data[(data < lower_threshold) | (data > upper_threshold)]

# Print the values of the potential outliers
print(outliers)
# Out:
# [-2.33434842  2.17664329 -2.19722124 -2.17396573 -2.35608477 -2.19296025
#  -2.21342667 -3.03464783 -2.13359626  2.91870974  2.53421929 -2.45715477
#   2.73741943 -2.33041212 -2.20306665 -2.65390004  2.23023114 -2.35660242
#   2.83099383 -2.52763637  2.24224591  2.42167548  2.51574041 -2.17158364
#   2.66472082  2.21709502 -2.30362501  2.38051601  2.18605657 -2.13338818
#   2.44867426 -2.73270696  3.69372898 -2.64735801 -2.28796844 -2.16276816
#   2.44010443  2.18122416 -2.77393392  2.47347354  2.33780069  6.69372898]

# %%
# Plot the data as a scatter plot
plt.scatter(range(len(data)), data)

# Mark the outlier points on the scatter plot
plt.scatter(range(len(outliers)), outliers, color='red')

# Show the plot
plt.show()

# %% [markdown]
# ## <h1><center>Other Forms of Statistical Distribution</center></h1>
#
#
# ***
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Uniform Distribution
#
# A uniform distribution is a distribution where all values within a certain range are equally likely to occur. This distribution is often used to model events where the outcome is equally likely to be any value within a certain range. [27]

# %%
# Generate 1000 random values from a uniform distribution with a low of 0 and a high of 1
data = np.random.uniform(low=0, high=1, size=1000)

# Print the first 10 values of the data
print(data[:10])
# Out:
# [0.77095255 0.52893301 0.67042149 0.08853184 0.07362447 0.23840013
#  0.74953251 0.06936171 0.04658235 0.16010999]

# %%
# Plot the data as a histogram
plt.hist(data, bins=50)

# Show the plot
plt.show()

# %% [markdown]
# The histogram above shows a flat distribution, indicating that all values within the range 0 to 1 are equally likely to occur.

# %% [markdown]
# ### Exponential Distribution
#
# An exponential distribution is a continuous probability distribution that describes the time between events in a Poisson process. This distribution is often used to model the time between events such as the time between customer arrivals at a store or the time between failures in a system.

# %%
# Generate 1000 random values from an exponential distribution with a rate of 1
data = np.random.exponential(scale=1, size=1000)

# Print the first 10 values of the data
print(data[:10])
# Out:
# [3.28686891 3.54368453 0.59818052 0.62811572 0.1210481  0.07455333
#  0.47162435 1.71711798 1.88208323 2.51224152]

# %%
# Plot the data as a histogram
plt.hist(data, bins=50)

# Show the plot
plt.show()

# %% [markdown]
# The histogram shows a skewed distribution with a long tail, indicating that the data is distributed exponentially.

# %% [markdown]
# ### Poisson Distribution
#
# A Poisson distribution is a discrete probability distribution that describes the number of events that occur in a fixed time interval. This distribution is often used to model the number of events such as the number of customers arriving at a store or the number of errors in a system.

# %%
# Generate 1000 random values from a Poisson distribution with a rate of 1
data = np.random.poisson(lam=1, size=1000)

# Print the first 10 values of the data
print(data[:10])
# Out:
# [1 2 0 1 1 0 0 2 0 1]

# %%
# Plot the data as a histogram
plt.hist(data, bins=50)

# Show the plot
plt.show()

# %% [markdown]
# The histogram shows a skewed distribution with a long tail, indicating that the data is distributed according to a Poisson distribution.

# %% [markdown]
# ### Binomial Distribution
#
# A binomial distribution is a discrete probability distribution that describes the number of successes in a sequence of independent Bernoulli trials. This distribution is often used to model the number of successes in a series of independent experiments, such as the number of heads in a series of coin flips or the number of customers who make a purchase after viewing an advertisement.

# %%
# Generate 1000 random values from a binomial distribution with 10 trials and a probability of 0.5
data = np.random.binomial(n=10, p=0.5, size=1000)

# Print the first 10 values of the data
print(data[:10])
# Out:
# [4 3 5 6 4 5 5 4 3 4]

# %%
# Plot the data as a histogram
plt.hist(data, bins=50)

# Show the plot
plt.show()

# %% [markdown]
# The histogram is skewed to the right, indicating that the distribution is skewed towards higher values. This is expected for a binomial distribution with a probability of 0.5, as there is a higher probability of success for each trial.

# %% [markdown]
# ### Gamma Distribution
#
# ***
#
# A gamma distribution is a continuous probability distribution that is often used to model the time between events in a Poisson process with a rate parameter. This distribution is often used to model the time between events such as the time between failures in a system or the time between earthquakes.

# %%
# Generate 1000 random values from a gamma distribution with a shape of 2 and a scale of 1
data = np.random.gamma(shape=2, scale=1, size=1000)

# Print the first 10 values of the data
print(data[:10])
# Out:
# [3.79894762 0.83717301 0.65446096 0.45880858 2.55416856 3.72739945
#  0.57859702 1.94667499 1.32026329 0.24510473]

# %%
# Plot the data as a histogram
plt.hist(data, bins=50)

# Show the plot
plt.show()

# %% [markdown]
# In this case, the histogram is skewed to the right because the shape parameter is 2, which leads to a higher frequency of higher values in the distribution.

# %% [markdown]
# ## <h1><center>Conclusion</center></h1>
#
# ***
#
# Throughout this project we have looked in detail at the Normal Distribution and explored its uses.
#
#
# - The Normal Distribution is a widely occurring distribution: Many real-world phenomena, such as human heights and intelligence test scores, are approximately normally distributed. This means that the normal distribution can be used to model and understand a wide range of data.
#
#
# - It is defined by only two parameters: The normal distribution is defined by its mean and standard deviation, which makes it relatively simple to work with compared to other distributions.
#
#
# - It is asymptotic: The normal distribution approaches but never touches the x-axis as it extends towards infinity in either direction. This property makes it a good choice for modeling data that is unbounded.
#
#
# - It is unimodal: The normal distribution is unimodal, meaning it has a single peak. This makes it a useful tool for understanding data that is centered around a single value.
#
#
# - It is used in many statistical tests: The normal distribution is used in various statistical tests such as the t-test and the F-test. It is also used in statistical modeling and machine learning algorithms, such as linear regression and the Naive Bayes classifier.
#
#
# - It is a good approximation for many real-world phenomena: The normal distribution is often used to understand the distribution of physical and biological phenomena, such as the heights of individuals or the lifespans of certain species.

# %% [markdown]
# ## <h1><center>References</center></h1>
#
# ***
#
# [1] Investopedia, Normal Distribution. https://www.investopedia.com/terms/n/normaldistribution.asp
#
# [2] Simply Psychology, Normal Distribution. https://www.simplypsychology.org/normal-distribution.html
#
# [3] Britannica, Normal Distribution. https://www.britannica.com/topic/normal-distribution
#
# [4] Sribbr, Normal Distribution. https://www.scribbr.com/statistics/normal-distribution/
#
# [5] Empirical Rule. https://www.wallstreetmojo.com/empirical-rule/
#
# [6] Mean, Median Mode. Statistics How To. https://www.statisticshowto.com/probability-and-statistics/statistics-definitions/mean-median-mode/
#
# [7] Finding the Mode of a List. https://stackoverflow.com/questions/10797819/finding-the-mode-of-a-list
#
# [8] Normal Origin. https://condor.depaul.edu/ntiourir/NormalOrigin.htm
#
# [9] Numpy.Random.Normal. https://numpy.org/devdocs/reference/random/generated/numpy.random.normal.html
#
# [10] PSU.edu, Normal Distribution. https://www.me.psu.edu/casestudy/Statistics/normal.htm#:~:text=One%20reason%20the%20normal%20distribution,psychological%20variables%20approximately%20normally%20distributed.
#
# [11] Statistics by Jim, Normal Distribution. https://statisticsbyjim.com/basics/normal-distribution/
#
# [12] Indeed.ie, Normal Distribution. https://ie.indeed.com/career-advice/career-development/normal-distribution
#
# [13] Real Life Examples of Normal Distribution. https://studiousguy.com/real-life-examples-normal-distribution/
#
# [14] Ian McLoughlin Randomness pt.2 Notebook. https://github.com/ianmcloughlin/2223-S1-fund-data-analysis/blob/main/notebooks/02-randomness.ipynb
#
# [15] Slideshare, Normal Distribution. https://www.slideshare.net/dsaadeddin/normal-distribution-77299816
#
# [16] Z-Score. https://www.simplypsychology.org/z-score.html
#
# [17] Z- Table. https://statisticsbyjim.com/hypothesis-testing/z-table/
#
# [18] Central Limit Theorem. https://www.investopedia.com/terms/c/central_limit_theorem.asp
#
# [19] Central Limit Theorem Real Life Examples. https://www.statology.org/central-limit-theorem-real-life-examples/
#
# [20] Scipy Stats Norm. https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.norm.html
#
# [21] Confidence Interval on the Mean. https://onlinestatbook.com/2/estimation/mean.html
#
# [22] Outliers. http://www.cs.uni.edu/~campbell/stat/normfact.html
#
# [23] How To Handle Outliers. https://medium.com/@piyushsharma161/how-to-handle-outliers-2f8ab630f68d
#
# [24] Numpy Clip in Python. https://www.geeksforgeeks.org/numpy-clip-in-python/
#
# [25] Inter Quantile Range. https://careerfoundry.com/en/blog/data-analytics/how-to-find-outliers/
#
# [26] Removing Outliers Standard Deviation. https://www.kdnuggets.com/2017/02/removing-outliers-standard-deviation-python.html
#
# [27] Uniform Distribution. https://www.itl.nist.gov/div898/handbook/eda/section3/eda3662.htm
